# %%
import requests
import numpy as np
import pandas as pd

# variable for ticker symbol
ticker = 'AAPL'

# API Key (DO NOT PUSH UNTIL HIDDEN)
fmp_api_key = ''

# API request for income statement variable
IS = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{ticker}?apikey={fmp_api_key}').json()

# calculates revvenue growth from previous year (Would like to expand this to get 
# average across last 5 years to make a ten year model)
revenue_growth = (IS[0]['revenue'] - IS[1]['revenue'])/ IS[1]['revenue']

print(revenue_growth)
# Out:
# 0.055120803769784836

# %%
# Creates Percentage of Sales Income Statement
# varable for next income in the income statement
net_income = IS[0]['netIncome']

# API Request for balance sheet statement
BS = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{ticker}?apikey={fmp_api_key}').json()

# Cleaning income statement call into a dataframe and 
# calculating the income statement as a percentage of revenue
income_statement = pd.DataFrame.from_dict(IS[0], orient = 'index')
income_statement = income_statement[6:-2] 
income_statement.columns = ['current_year']
income_statement['as_%_of_revenue'] = income_statement / income_statement.iloc[0]

# Forecasting income statement growth for next 5 years
income_statement['next_year'] = (income_statement['current_year']['revenue'] * (1+revenue_growth)) *income_statement['as_%_of_revenue']
income_statement['next_2_years'] = (income_statement['next_year']['revenue'] * (1+revenue_growth)) *income_statement['as_%_of_revenue']
income_statement['next_3_years'] = (income_statement['next_2_years']['revenue'] * (1+revenue_growth)) *income_statement['as_%_of_revenue']
income_statement['next_4_years'] = (income_statement['next_3_years']['revenue'] * (1+revenue_growth)) *income_statement['as_%_of_revenue']
income_statement['next_5_years'] = (income_statement['next_4_years']['revenue'] * (1+revenue_growth)) *income_statement['as_%_of_revenue']

# Prints Income Statement as percentage of sales
income_statement
# Out:
#                                          current_year as_%_of_revenue  \
# revenue                                  274515000000             1.0
# costOfRevenue                            169559000000        0.617668
# grossProfit                              104956000000        0.382332
# grossProfitRatio                             0.382332             0.0
# researchAndDevelopmentExpenses            18752000000         0.06831
# generalAndAdministrativeExpenses          19916000000         0.07255
# sellingAndMarketingExpenses                       0.0             0.0
# sellingGeneralAndAdministrativeExpenses   19916000000         0.07255
# otherExpenses                                     0.0             0.0
# operatingExpenses                         38668000000        0.140859
# costAndExpenses                          208227000000        0.758527
# interestExpense                            2873000000        0.010466
# depreciationAndAmortization               11056000000        0.040275
# ebitda                                    81020000000        0.295139
# ebitdaratio                                  0.295139             0.0
# operatingIncome                           66288000000        0.241473
# operatingIncomeRatio                         0.241473             0.0
# totalOtherIncomeExpensesNet                -803000000       -0.002925
# incomeBeforeTax                           67091000000        0.244398
# incomeBeforeTaxRatio                         0.244398             0.0
# incomeTaxExpense                           9680000000        0.035262
# netIncome                                 57411000000        0.209136
# netIncomeRatio                               0.209136             0.0
# eps                                              3.31             0.0
# epsdiluted                                       3.28             0.0
# weightedAverageShsOut                     17352119000         0.06321
# weightedAverageShsOutDil                  17528214000        0.063852
#
#                                                    next_year  \
# revenue                                  289646487446.862488
# costOfRevenue                             178905228366.40094
# grossProfit                              110741259080.461533
# grossProfitRatio                                    0.403407
# researchAndDevelopmentExpenses            19785625312.291008
# generalAndAdministrativeExpenses          21013785927.879036
# sellingAndMarketingExpenses                              0.0
# sellingGeneralAndAdministrativeExpenses   21013785927.879036
# otherExpenses                                            0.0
# operatingExpenses                         40799411240.170036
# costAndExpenses                          219704639606.570984
# interestExpense                            3031362069.230592
# depreciationAndAmortization               11665415606.478741
# ebitda                                    85485887521.427963
# ebitdaratio                                         0.311407
# operatingIncome                           69941847840.291504
# operatingIncomeRatio                                0.254783
# totalOtherIncomeExpensesNet                -847262005.427137
# incomeBeforeTax                           70789109845.718643
# incomeBeforeTaxRatio                                 0.25787
# incomeTaxExpense                          10213569380.491518
# netIncome                                 60575540465.227119
# netIncomeRatio                                      0.220664
# eps                                                  3.49245
# epsdiluted                                          3.460796
# weightedAverageShsOut                     18308581746.388958
# weightedAverageShsOutDil                  18494383244.328796
#
#                                                 next_2_years  \
# revenue                                  305612034644.028442
# costOfRevenue                            188766628352.573853
# grossProfit                              116845406291.454559
# grossProfitRatio                                    0.425643
# researchAndDevelopmentExpenses            20876224882.592289
# generalAndAdministrativeExpenses          22172082698.469921
# sellingAndMarketingExpenses                              0.0
# sellingGeneralAndAdministrativeExpenses   22172082698.469921
# otherExpenses                                            0.0
# operatingExpenses                         43048307581.062202
# costAndExpenses                          231814935933.636078
# interestExpense                             3198453183.00382
# depreciationAndAmortization               12308422691.016441
# ebitda                                    90197938352.582489
# ebitdaratio                                         0.328572
# operatingIncome                           73797098710.392349
# operatingIncomeRatio                                0.268827
# totalOtherIncomeExpensesNet                -893963768.169881
# incomeBeforeTax                           74691062478.562241
# incomeBeforeTaxRatio                                0.272084
# incomeTaxExpense                          10776549534.102673
# netIncome                                 63914512944.459564
# netIncomeRatio                                      0.232827
# eps                                                 3.684957
# epsdiluted                                          3.651558
# weightedAverageShsOut                     19317765488.134727
# weightedAverageShsOutDil                  19513808513.982639
#
#                                                 next_3_years  \
# revenue                                  322457615635.326599
# costOfRevenue                            199171596632.279968
# grossProfit                                123286019003.0466
# grossProfitRatio                                    0.449105
# researchAndDevelopmentExpenses            22026939177.799557
# generalAndAdministrativeExpenses          23394225718.059723
# sellingAndMarketingExpenses                              0.0
# sellingGeneralAndAdministrativeExpenses   23394225718.059723
# otherExpenses                                            0.0
# operatingExpenses                         45421164895.859276
# costAndExpenses                          244592761528.139252
# interestExpense                            3374754493.271018
# depreciationAndAmortization               12986872842.883524
# ebitda                                     95169721212.95433
# ebitdaratio                                         0.346683
# operatingIncome                           77864854107.187332
# operatingIncomeRatio                                0.283645
# totalOtherIncomeExpensesNet                 -943239769.61247
# incomeBeforeTax                           78808093876.799805
# incomeBeforeTaxRatio                                0.287081
# incomeTaxExpense                          11370561606.287312
# netIncome                                 67437532270.512489
# netIncomeRatio                                      0.245661
# eps                                                 3.888074
# epsdiluted                                          3.852835
# weightedAverageShsOut                     20382576248.876923
# weightedAverageShsOutDil                   20589425323.88303
#
#                                                 next_4_years  \
# revenue                                  340231738590.834106
# costOfRevenue                            210150095126.762604
# grossProfit                              130081643464.071487
# grossProfitRatio                                     0.47386
# researchAndDevelopmentExpenses            23241081769.868027
# generalAndAdministrativeExpenses          24683734243.210945
# sellingAndMarketingExpenses                              0.0
# sellingGeneralAndAdministrativeExpenses   24683734243.210945
# otherExpenses                                            0.0
# operatingExpenses                         47924816013.078964
# costAndExpenses                          258074911139.841583
# interestExpense                            3560773673.465808
# depreciationAndAmortization               13702719712.439253
# ebitda                                   100415552740.758713
# ebitdaratio                                         0.365793
# operatingIncome                           82156827450.992523
# operatingIncomeRatio                                 0.29928
# totalOtherIncomeExpensesNet                -995231903.861136
# incomeBeforeTax                           83152059354.853653
# incomeBeforeTaxRatio                                0.302905
# incomeTaxExpense                          11997316101.339724
# netIncome                                 71154743253.513931
# netIncomeRatio                                      0.259202
# eps                                                 4.102388
# epsdiluted                                          4.065206
# weightedAverageShsOut                     21506080234.613941
# weightedAverageShsOutDil                  21724330996.893425
#
#                                                 next_5_years
# revenue                                  358985585489.952209
# costOfRevenue                            221733737282.446503
# grossProfit                              137251848207.505676
# grossProfitRatio                                    0.499979
# researchAndDevelopmentExpenses            24522148877.502449
# generalAndAdministrativeExpenses          26044321514.736492
# sellingAndMarketingExpenses                              0.0
# sellingGeneralAndAdministrativeExpenses   26044321514.736492
# otherExpenses                                            0.0
# operatingExpenses                         50566470392.238937
# costAndExpenses                          272300207674.685455
# interestExpense                            3757046380.389534
# depreciationAndAmortization                14458024636.82098
# ebitda                                   105950538718.816559
# ebitdaratio                                         0.385955
# operatingIncome                           86685377815.266754
# operatingIncomeRatio                                0.315776
# totalOtherIncomeExpensesNet               -1050089886.339295
# incomeBeforeTax                           87735467701.606049
# incomeBeforeTaxRatio                                0.319602
# incomeTaxExpense                          12658617807.925751
# netIncome                                 75076849893.680298
# netIncomeRatio                                      0.273489
# eps                                                 4.328515
# epsdiluted                                          4.289284
# weightedAverageShsOut                     22691512663.083344
# weightedAverageShsOutDil                   22921793582.80304

# %%
# Cleans Balance Sheet
balance_sheet = pd.DataFrame.from_dict(BS[0],orient='index')
balance_sheet = balance_sheet[6:-2]
balance_sheet.columns = ['current_year']
balance_sheet['as_%_of_revenue'] = balance_sheet / income_statement['current_year'].iloc[0]

# Forecasts as percentage of revenue
balance_sheet['next_year'] = income_statement['next_year'] ['revenue'] * balance_sheet['as_%_of_revenue']
balance_sheet['next_2_years'] = income_statement['next_year'] ['revenue'] * balance_sheet['as_%_of_revenue']
balance_sheet['next_3_years'] = income_statement['next_2_years'] ['revenue'] * balance_sheet['as_%_of_revenue']
balance_sheet['next_4_years'] = income_statement['next_3_years'] ['revenue'] * balance_sheet['as_%_of_revenue']
balance_sheet['next_5_years'] = income_statement['next_4_years'] ['revenue'] * balance_sheet['as_%_of_revenue']

# Prints Balance Sheet
balance_sheet
# Out:
#                                          current_year as_%_of_revenue  \
# cashAndCashEquivalents                    38016000000        0.138484
# shortTermInvestments                      52927000000        0.192802
# cashAndShortTermInvestments               90943000000        0.331286
# netReceivables                            37445000000        0.136404
# inventory                                  4061000000        0.014793
# otherCurrentAssets                        11264000000        0.041032
# totalCurrentAssets                       143713000000        0.523516
# propertyPlantEquipmentNet                 36766000000        0.133931
# goodwill                                          0.0             0.0
# intangibleAssets                                  0.0             0.0
# goodwillAndIntangibleAssets                       0.0             0.0
# longTermInvestments                      100887000000         0.36751
# taxAssets                                         0.0             0.0
# otherNonCurrentAssets                     42522000000        0.154899
# totalNonCurrentAssets                    180175000000        0.656339
# otherAssets                               90482000000        0.329607
# totalAssets                              323888000000        1.179855
# accountPayables                           42296000000        0.154075
# shortTermDebt                             13769000000        0.050158
# taxPayables                                       0.0             0.0
# deferredRevenue                            6643000000        0.024199
# otherCurrentLiabilities                   42684000000        0.155489
# totalCurrentLiabilities                  105392000000        0.383921
# longTermDebt                              98667000000        0.359423
# deferredRevenueNonCurrent                         0.0             0.0
# deferredTaxLiabilitiesNonCurrent                  0.0             0.0
# otherNonCurrentLiabilities                54490000000        0.198496
# totalNonCurrentLiabilities               153157000000        0.557919
# otherLiabilities                                  0.0             0.0
# totalLiabilities                         258549000000        0.941839
# commonStock                               50779000000        0.184977
# retainedEarnings                          14966000000        0.054518
# accumulatedOtherComprehensiveIncomeLoss    -406000000       -0.001479
# othertotalStockholdersEquity                      0.0             0.0
# totalStockholdersEquity                   65339000000        0.238016
# totalLiabilitiesAndStockholdersEquity    323888000000        1.179855
# totalInvestments                         153814000000        0.560312
# totalDebt                                112436000000        0.409581
# netDebt                                   74420000000        0.271096
#
#                                                    next_year  \
# cashAndCashEquivalents                    40111472476.112144
# shortTermInvestments                      55844378781.123405
# cashAndShortTermInvestments                95955851257.23555
# netReceivables                            39508998497.159592
# inventory                                  4284845584.109096
# otherCurrentAssets                        11884880733.662857
# totalCurrentAssets                       151634576072.167084
# propertyPlantEquipmentNet                 38792571471.399902
# goodwill                                                 0.0
# intangibleAssets                                         0.0
# goodwillAndIntangibleAssets                              0.0
# longTermInvestments                      106447972529.922287
# taxAssets                                                0.0
# otherNonCurrentAssets                     44865846817.898796
# totalNonCurrentAssets                    190106390819.220978
# otherAssets                               95469440566.697678
# totalAssets                              341740966891.388062
# accountPayables                           44627389516.246826
# shortTermDebt                             14527958347.106167
# taxPayables                                              0.0
# deferredRevenue                            7009167499.442681
# otherCurrentLiabilities                   45036776388.109497
# totalCurrentLiabilities                  111201291750.905151
# longTermDebt                              104105604345.55336
# deferredRevenueNonCurrent                                0.0
# deferredTaxLiabilitiesNonCurrent                         0.0
# otherNonCurrentLiabilities                57493532597.415581
# totalNonCurrentLiabilities               161599136942.968933
# otherLiabilities                                         0.0
# totalLiabilities                         272800428693.874115
# commonStock                                 53577979294.6259
# retainedEarnings                          15790937949.218599
# accumulatedOtherComprehensiveIncomeLoss    -428379046.330533
# othertotalStockholdersEquity                             0.0
# totalStockholdersEquity                   68940538197.513977
# totalLiabilitiesAndStockholdersEquity    341740966891.388062
# totalInvestments                         162292351311.045685
# totalDebt                                118633562692.659531
# netDebt                                   78522090216.547394
#
#                                                 next_2_years  \
# cashAndCashEquivalents                    40111472476.112144
# shortTermInvestments                      55844378781.123405
# cashAndShortTermInvestments                95955851257.23555
# netReceivables                            39508998497.159592
# inventory                                  4284845584.109096
# otherCurrentAssets                        11884880733.662857
# totalCurrentAssets                       151634576072.167084
# propertyPlantEquipmentNet                 38792571471.399902
# goodwill                                                 0.0
# intangibleAssets                                         0.0
# goodwillAndIntangibleAssets                              0.0
# longTermInvestments                      106447972529.922287
# taxAssets                                                0.0
# otherNonCurrentAssets                     44865846817.898796
# totalNonCurrentAssets                    190106390819.220978
# otherAssets                               95469440566.697678
# totalAssets                              341740966891.388062
# accountPayables                           44627389516.246826
# shortTermDebt                             14527958347.106167
# taxPayables                                              0.0
# deferredRevenue                            7009167499.442681
# otherCurrentLiabilities                   45036776388.109497
# totalCurrentLiabilities                  111201291750.905151
# longTermDebt                              104105604345.55336
# deferredRevenueNonCurrent                                0.0
# deferredTaxLiabilitiesNonCurrent                         0.0
# otherNonCurrentLiabilities                57493532597.415581
# totalNonCurrentLiabilities               161599136942.968933
# otherLiabilities                                         0.0
# totalLiabilities                         272800428693.874115
# commonStock                                 53577979294.6259
# retainedEarnings                          15790937949.218599
# accumulatedOtherComprehensiveIncomeLoss    -428379046.330533
# othertotalStockholdersEquity                             0.0
# totalStockholdersEquity                   68940538197.513977
# totalLiabilitiesAndStockholdersEquity    341740966891.388062
# totalInvestments                         162292351311.045685
# totalDebt                                118633562692.659531
# netDebt                                   78522090216.547394
#
#                                                 next_3_years  \
# cashAndCashEquivalents                    42322449079.385048
# shortTermInvestments                       58922565825.56324
# cashAndShortTermInvestments              101245014904.948288
# netReceivables                             41686766250.46225
# inventory                                  4521029716.734603
# otherCurrentAssets                        12539984912.410383
# totalCurrentAssets                       159992795784.555511
# propertyPlantEquipmentNet                 40930849191.200294
# goodwill                                                 0.0
# intangibleAssets                                         0.0
# goodwillAndIntangibleAssets                              0.0
# longTermInvestments                      112315470335.435577
# taxAssets                                                0.0
# otherNonCurrentAssets                     47338888356.313416
# totalNonCurrentAssets                     200585207882.94928
# otherAssets                              100731792866.185745
# totalAssets                              360578003667.504761
# accountPayables                           47087287096.529617
# shortTermDebt                             15328751088.332613
# taxPayables                                              0.0
# deferredRevenue                            7395518445.769014
# otherCurrentLiabilities                   47519239701.822159
# totalCurrentLiabilities                    117330796332.4534
# longTermDebt                             109843988934.019455
# deferredRevenueNonCurrent                                0.0
# deferredTaxLiabilitiesNonCurrent                         0.0
# otherNonCurrentLiabilities                60662622325.749451
# totalNonCurrentLiabilities               170506611259.768921
# otherLiabilities                                         0.0
# totalLiabilities                         287837407592.222351
# commonStock                               56531240577.706573
# retainedEarnings                          16661347141.258326
# accumulatedOtherComprehensiveIncomeLoss    -451991643.682405
# othertotalStockholdersEquity                             0.0
# totalStockholdersEquity                   72740596075.282501
# totalLiabilitiesAndStockholdersEquity    360578003667.504761
# totalInvestments                          171238036160.99881
# totalDebt                                125172740022.352081
# netDebt                                   82850290942.967041
#
#                                                 next_4_years  \
# cashAndCashEquivalents                    44655296490.146538
# shortTermInvestments                      62170425014.046341
# cashAndShortTermInvestments              106825721504.192871
# netReceivables                            43984574312.750862
# inventory                                  4770232508.588097
# otherCurrentAssets                        13231198960.043417
# totalCurrentAssets                       168811727285.575226
# propertyPlantEquipmentNet                 43186990497.599098
# goodwill                                                 0.0
# intangibleAssets                                         0.0
# goodwillAndIntangibleAssets                              0.0
# longTermInvestments                      118506389336.106201
# taxAssets                                                0.0
# otherNonCurrentAssets                      49948245932.08152
# totalNonCurrentAssets                    211641625765.786804
# otherAssets                              106284210254.141388
# totalAssets                              380453353051.362061
# accountPayables                           49682776208.628944
# shortTermDebt                             16173684169.108471
# taxPayables                                              0.0
# deferredRevenue                            7803165366.794072
# otherCurrentLiabilities                    50138538388.71566
# totalCurrentLiabilities                  123798164133.247147
# longTermDebt                             115898677893.341965
# deferredRevenueNonCurrent                                0.0
# deferredTaxLiabilitiesNonCurrent                         0.0
# otherNonCurrentLiabilities                64006394827.127655
# totalNonCurrentLiabilities               179905072720.469604
# otherLiabilities                                         0.0
# totalLiabilities                         303703236853.716797
# commonStock                               59647287996.452835
# retainedEarnings                          17579733987.571892
# accumulatedOtherComprehensiveIncomeLoss    -476905786.379406
# othertotalStockholdersEquity                             0.0
# totalStockholdersEquity                   76750116197.645309
# totalLiabilitiesAndStockholdersEquity    380453353051.362061
# totalInvestments                         180676814350.152527
# totalDebt                                132072362062.450439
# netDebt                                   87417065572.303909
#
#                                                 next_5_years
# cashAndCashEquivalents                    47116732325.261459
# shortTermInvestments                      65597308811.529701
# cashAndShortTermInvestments              112714041136.791168
# netReceivables                            46409039402.341522
# inventory                                  5033171558.630229
# otherCurrentAssets                         13960513281.55895
# totalCurrentAssets                       178116765379.321838
# propertyPlantEquipmentNet                 45567492126.224815
# goodwill                                                 0.0
# intangibleAssets                                         0.0
# goodwillAndIntangibleAssets                              0.0
# longTermInvestments                      125038556768.167419
# taxAssets                                                0.0
# otherNonCurrentAssets                     52701433394.748734
# totalNonCurrentAssets                    223307482289.140961
# otherAssets                              112142681351.386444
# totalAssets                               401424247668.46283
# accountPayables                           52421330766.762909
# shortTermDebt                             17065190640.428371
# taxPayables                                              0.0
# deferredRevenue                            8233282113.760308
# otherCurrentLiabilities                   52902214924.543877
# totalCurrentLiabilities                  130622018445.495453
# longTermDebt                             122287106174.678345
# deferredRevenueNonCurrent                                0.0
# deferredTaxLiabilitiesNonCurrent                         0.0
# otherNonCurrentLiabilities                67534478756.405121
# totalNonCurrentLiabilities               189821584931.083466
# otherLiabilities                                         0.0
# totalLiabilities                         320443603376.578918
# commonStock                               62935094453.505142
# retainedEarnings                          18548743055.025856
# accumulatedOtherComprehensiveIncomeLoss      -503193216.6471
# othertotalStockholdersEquity                             0.0
# totalStockholdersEquity                   80980644291.883896
# totalLiabilitiesAndStockholdersEquity     401424247668.46283
# totalInvestments                         190635865579.697113
# totalDebt                                 139352296815.10672
# netDebt                                   92235564489.845276

# %%
# Forecasts Free Cash Flows, Net Income, Depreciation, Receivables, Inventory, Payables, Cash from Operations, & CAPEX 
# for Next Year
CF_forecast = {}
CF_forecast['next_year'] = {}
CF_forecast['next_year']['netIncome'] = income_statement['next_year']['netIncome']
CF_forecast['next_year']['inc_depreciation'] = income_statement['next_year']['depreciationAndAmortization']
CF_forecast['next_year']['inc_receivables'] = balance_sheet['next_year']['netReceivables'] - balance_sheet['current_year']['netReceivables']
CF_forecast['next_year']['inc_inventory'] = balance_sheet['next_year']['inventory'] - balance_sheet['current_year']['inventory']
CF_forecast['next_year']['inc_payables'] = balance_sheet['next_year']['accountPayables'] - balance_sheet['current_year']['accountPayables']
CF_forecast['next_year']['CF_operations'] = CF_forecast['next_year']['netIncome'] + CF_forecast['next_year']['inc_depreciation'] + (CF_forecast['next_year']['inc_receivables'] * -1) + (CF_forecast['next_year']['inc_inventory'] *-1) + CF_forecast['next_year']['inc_payables']
CF_forecast['next_year']['CAPEX'] = balance_sheet['next_year']['propertyPlantEquipmentNet'] - balance_sheet['current_year']['propertyPlantEquipmentNet'] + income_statement['next_year']['depreciationAndAmortization']

CF_forecast['next_year']['FCF'] = CF_forecast['next_year']['CAPEX'] + CF_forecast['next_year']['CF_operations']

# Forecasts Free Cash Flows, Net Income, Depreciation, Receivables, Inventory, Payables, Cash from Operations, & CAPEX 
# for Next Two Years
CF_forecast['next_2_years'] = {}
CF_forecast['next_2_years']['netIncome'] = income_statement['next_2_years']['netIncome']

CF_forecast['next_2_years']['inc_depreciation'] = income_statement['next_2_years']['depreciationAndAmortization']
CF_forecast['next_2_years']['inc_receivables'] = balance_sheet['next_2_years']['netReceivables'] - balance_sheet['next_year']['netReceivables']
CF_forecast['next_2_years']['inc_inventory'] = balance_sheet['next_2_years']['inventory'] - balance_sheet['next_year']['inventory']
CF_forecast['next_2_years']['inc_payables'] = balance_sheet['next_2_years']['accountPayables'] - balance_sheet['next_year']['accountPayables']
CF_forecast['next_2_years']['CF_operations'] = CF_forecast['next_2_years']['netIncome'] + CF_forecast['next_2_years']['inc_depreciation'] + (CF_forecast['next_2_years']['inc_receivables'] * -1) + (CF_forecast['next_2_years']['inc_inventory'] *-1) + CF_forecast['next_2_years']['inc_payables']
CF_forecast['next_2_years']['CAPEX'] = balance_sheet['next_2_years']['propertyPlantEquipmentNet'] - balance_sheet['next_year']['propertyPlantEquipmentNet'] + income_statement['next_2_years']['depreciationAndAmortization']
CF_forecast['next_2_years']['FCF'] = CF_forecast['next_2_years']['CAPEX'] + CF_forecast['next_2_years']['CF_operations']

# Forecasts Free Cash Flows, Net Income, Depreciation, Receivables, Inventory, Payables, Cash from Operations, & CAPEX 
# for Next Three Years
CF_forecast['next_3_years'] = {}
CF_forecast['next_3_years']['netIncome'] = income_statement['next_3_years']['netIncome']

CF_forecast['next_3_years']['inc_depreciation'] = income_statement['next_3_years']['depreciationAndAmortization'] 
CF_forecast['next_3_years']['inc_receivables'] = balance_sheet['next_3_years']['netReceivables'] - balance_sheet['next_2_years']['netReceivables']
CF_forecast['next_3_years']['inc_inventory'] = balance_sheet['next_3_years']['inventory'] - balance_sheet['next_2_years']['inventory']
CF_forecast['next_3_years']['inc_payables'] = balance_sheet['next_3_years']['accountPayables'] - balance_sheet['next_2_years']['accountPayables']
CF_forecast['next_3_years']['CF_operations'] = CF_forecast['next_3_years']['netIncome'] + CF_forecast['next_3_years']['inc_depreciation'] + (CF_forecast['next_3_years']['inc_receivables'] * -1) + (CF_forecast['next_3_years']['inc_inventory'] *-1) + CF_forecast['next_3_years']['inc_payables']
CF_forecast['next_3_years']['CAPEX'] = balance_sheet['next_3_years']['propertyPlantEquipmentNet'] - balance_sheet['next_2_years']['propertyPlantEquipmentNet'] + income_statement['next_3_years']['depreciationAndAmortization']
CF_forecast['next_3_years']['FCF'] = CF_forecast['next_3_years']['CAPEX'] + CF_forecast['next_3_years']['CF_operations']

# Forecasts Free Cash Flows, Net Income, Depreciation, Receivables, Inventory, Payables, Cash from Operations, & CAPEX 
# for Next Four Years

CF_forecast['next_4_years'] = {}
CF_forecast['next_4_years']['netIncome'] = income_statement['next_4_years']['netIncome']

CF_forecast['next_4_years']['inc_depreciation'] = income_statement['next_4_years']['depreciationAndAmortization']
CF_forecast['next_4_years']['inc_receivables'] = balance_sheet['next_4_years']['netReceivables'] - balance_sheet['next_3_years']['netReceivables']
CF_forecast['next_4_years']['inc_inventory'] = balance_sheet['next_4_years']['inventory'] - balance_sheet['next_3_years']['inventory']
CF_forecast['next_4_years']['inc_payables'] = balance_sheet['next_4_years']['accountPayables'] - balance_sheet['next_3_years']['accountPayables']
CF_forecast['next_4_years']['CF_operations'] = CF_forecast['next_4_years']['netIncome'] + CF_forecast['next_4_years']['inc_depreciation'] + (CF_forecast['next_4_years']['inc_receivables'] * -1) + (CF_forecast['next_4_years']['inc_inventory'] *-1) + CF_forecast['next_4_years']['inc_payables']
CF_forecast['next_4_years']['CAPEX'] = balance_sheet['next_4_years']['propertyPlantEquipmentNet'] - balance_sheet['next_3_years']['propertyPlantEquipmentNet'] + income_statement['next_4_years']['depreciationAndAmortization']
CF_forecast['next_4_years']['FCF'] = CF_forecast['next_4_years']['CAPEX'] + CF_forecast['next_4_years']['CF_operations']

# Forecasts Free Cash Flows, Net Income, Depreciation, Receivables, Inventory, Payables, Cash from Operations, & CAPEX 
# for Next Five Years

CF_forecast['next_5_years'] = {}
CF_forecast['next_5_years']['netIncome'] = income_statement['next_5_years']['netIncome']

CF_forecast['next_5_years']['inc_depreciation'] = income_statement['next_5_years']['depreciationAndAmortization'] 
CF_forecast['next_5_years']['inc_receivables'] = balance_sheet['next_5_years']['netReceivables'] - balance_sheet['next_4_years']['netReceivables']
CF_forecast['next_5_years']['inc_inventory'] = balance_sheet['next_5_years']['inventory'] - balance_sheet['next_4_years']['inventory']
CF_forecast['next_5_years']['inc_payables'] = balance_sheet['next_5_years']['accountPayables'] - balance_sheet['next_4_years']['accountPayables']
CF_forecast['next_5_years']['CF_operations'] = CF_forecast['next_5_years']['netIncome'] + CF_forecast['next_5_years']['inc_depreciation'] + (CF_forecast['next_5_years']['inc_receivables'] * -1) + (CF_forecast['next_5_years']['inc_inventory'] *-1) + CF_forecast['next_5_years']['inc_payables']
CF_forecast['next_5_years']['CAPEX'] = balance_sheet['next_5_years']['propertyPlantEquipmentNet'] - balance_sheet['next_4_years']['propertyPlantEquipmentNet'] + income_statement['next_5_years']['depreciationAndAmortization']
CF_forecast['next_5_years']['FCF'] = CF_forecast['next_5_years']['CAPEX'] + CF_forecast['next_5_years']['CF_operations']

CF_forecast
# Out:
# {'next_year': {'netIncome': 60575540465.22712,
#   'inc_depreciation': 11665415606.47874,
#   'inc_receivables': 2063998497.1595917,
#   'inc_inventory': 223845584.10909605,
#   'inc_payables': 2331389516.246826,
#   'CF_operations': 72284501506.68399,
#   'CAPEX': 13691987077.878643,
#   'FCF': 85976488584.56264},
#  'next_2_years': {'netIncome': 63914512944.459564,
#   'inc_depreciation': 12308422691.016441,
#   'inc_receivables': 0.0,
#   'inc_inventory': 0.0,
#   'inc_payables': 0.0,
#   'CF_operations': 76222935635.47601,
#   'CAPEX': 12308422691.016441,
#   'FCF': 88531358326.49246},
#  'next_3_years': {'netIncome': 67437532270.51249,
#   'inc_depreciation': 12986872842.883524,
#   'inc_receivables': 2177767753.302658,
#   'inc_inventory': 236184132.62550688,
#   'inc_payables': 2459897580.282791,
#   'CF_operations': 80470350807.75064,
#   'CAPEX': 15125150562.683916,
#   'FCF': 95595501370.43456},
#  'next_4_years': {'netIncome': 71154743253.51393,
#   'inc_depreciation': 13702719712.439253,
#   'inc_receivables': 2297808062.2886124,
#   'inc_inventory': 249202791.8534937,
#   'inc_payables': 2595489112.099327,
#   'CF_operations': 84905941223.9104,
#   'CAPEX': 15958861018.838057,
#   'FCF': 100864802242.74846},
#  'next_5_years': {'netIncome': 75076849893.6803,
#   'inc_depreciation': 14458024636.82098,
#   'inc_receivables': 2424465089.59066,
#   'inc_inventory': 262939050.04213238,
#   'inc_payables': 2738554558.1339645,
#   'CF_operations': 89586024949.00244,
#   'CAPEX': 16838526265.446697,
#   'FCF': 106424551214.44914}}

# %%
CF_forec = pd.DataFrame.from_dict(CF_forecast, orient='columns')
pd.options.display.float_format='{:,.0f}'.format

print(CF_forec)
# Out:
#                       next_year   next_2_years   next_3_years    next_4_years  \
# netIncome        60,575,540,465 63,914,512,944 67,437,532,271  71,154,743,254
# inc_depreciation 11,665,415,606 12,308,422,691 12,986,872,843  13,702,719,712
# inc_receivables   2,063,998,497              0  2,177,767,753   2,297,808,062
# inc_inventory       223,845,584              0    236,184,133     249,202,792
# inc_payables      2,331,389,516              0  2,459,897,580   2,595,489,112
# CF_operations    72,284,501,507 76,222,935,635 80,470,350,808  84,905,941,224
# CAPEX            13,691,987,078 12,308,422,691 15,125,150,563  15,958,861,019
# FCF              85,976,488,585 88,531,358,326 95,595,501,370 100,864,802,243
#
#                     next_5_years
# netIncome         75,076,849,894
# inc_depreciation  14,458,024,637
# inc_receivables    2,424,465,090
# inc_inventory        262,939,050
# inc_payables       2,738,554,558
# CF_operations     89,586,024,949
# CAPEX             16,838,526,265
# FCF              106,424,551,214
